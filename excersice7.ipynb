# %% [markdown]
# # Project: "Avian Analysis - Penguins Dataset"
# Dataset: sns.load_dataset('penguins')
# Goal: Differentiate penguin species by comparing multiple physical traits at once.
# * Adding Hue, Size, and Style: Build a sns.scatterplot() comparing bill_length_mm vs. bill_depth_mm. Make it 4-dimensional by assigning hue='species' (different colors for species), style='island' (different marker shapes for locations), and size='body_mass_g' (bubble sizes for weight).
# * Pair Plots: Run sns.pairplot(penguins, hue='species'). Have the students observe how this one line of code generates a massive grid of scatterplots and KDEs, instantly showing which variables easily separate the Adelie, Chinstrap, and Gentoo penguins.
# * Correlation & Heatmaps: Have them drop the categorical columns, calculate the correlation matrix (df.corr()), and visualize it using sns.heatmap(annot=True, cmap='coolwarm'). They should discover the strong positive correlation between flipper length and body mass.
# * Explain each of the graphs in details

# %% [markdown]
# ## Dataset: sns.load_dataset('penguins')

# %% [markdown]
# * Adding Hue, Size, and Style: Build a sns.scatterplot() comparing bill_length_mm vs. bill_depth_mm. Make it 4-dimensional by assigning hue='species' (different colors for species), style='island' (different marker shapes for locations), and size='body_mass_g' (bubble sizes for weight).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset('penguins')
# df

sns.scatterplot(data=df, x='bill_length_mm', y='bill_depth_mm', hue="species", style='island', size='body_mass_g')

plt.title("Multivariate Scatter Plot")
plt.xlabel("Length")
plt.ylabel("Depth")

plt.show()

# %% [markdown]
# ## Explain:
#
# * So this graph is call Multivariate scartter plot we using this to see the data more clearly by add hue and style on the scartter plot that why we call Multivariate scatter plot. For this graph we talking about the penguins Length and Depth. So depend on the the graph by we using scartter plot we see that the Variety Adelie penguins have length range between 40 to 45 and depth is mostly range 16 to 20. However, if we are looking on the Variety Chinstrap orange color mostly is Dream for the length is range between 43 to 55 adn the depth is 16 to 20. For the last one is Variety that stand by green color mostly is Biscoe and for the range is between is from 43 to 53, for the depth is 9 to 17. Conclusion, depend on the scartter on the graph we can say that it is "Clusters" they stay distinct groups.

# %% [markdown]
# * Pair Plots: Run sns.pairplot(penguins, hue='species'). Have the students observe how this one line of code generates a massive grid of scatterplots and KDEs, instantly showing which variables easily separate the Adelie, Chinstrap, and Gentoo penguins.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset('penguins')
# df

sns.pairplot(data=df, hue='species', diag_kind="hist")

plt.show()

# %% [markdown]
# ## Explain:
#
# * So this graph is call pariplot that we use to show relationship between various measurement data at the same time. By using to scartter plot and bar plot to show the graph and plot on the screen. So how can we understand that graph please take a look on the y_line you will we the letter take a note on that columns simalarly if we are looking on x_line we also see the letter of that graph also one graph have one note or one commed. For the note the graph we using to not what that graph are comparing with what. For example if we are looking on row 3 name "flipper_length_mm" and columns 2 name "bill_depth_mm" the name on the x_line we see that the scartter on the graph is "Clusters". So one more thing if the data in the row and columns do not the not the same it will output scartter plot. However, if the data is the same and the same name the graph will be show barplot or histograms.

# %% [markdown]
# * Correlation & Heatmaps: Have them drop the categorical columns, calculate the correlation matrix (df.corr()), and visualize it using sns.heatmap(annot=True, cmap='coolwarm'). They should discover the strong positive correlation between flipper length and body mass.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset('penguins')
df = df.select_dtypes(include=[float, int])

df = df.corr()

sns.heatmap(df, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix of Penguins Dataset")

plt.show()

# %% [markdown]
# ## Explain:
#
# * This graph is call heatmap if we are just take a look on that graph we do not understand what the graph mean we just see number in the columns of the graph. The highest number is number 1 have relationship with each other the most one. So this graph is call heatmap is showing only the number do not show the graph or showing us the bar. We can know what the data are compare by looking on the X_line and Y_line of the columns as the simalarly  pair plot. For the negative number it mean that also have relationship but just a little or only a few.
